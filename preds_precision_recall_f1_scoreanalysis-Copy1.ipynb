# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torchvision import transforms
import torch.nn as nn
from PIL import Image

class2num = {'broad leaves': 0, 'coniferous tree': 1, 'grass land': 2, 'hard ground': 3, 'leafless': 4, 'stalk': 5, 'stone': 6, 'trunk': 7, 'water': 8, 'wire': 9}
num2class = {0: 'broad leaves', 1: 'coniferous tree', 2: 'grass land', 3: 'hard ground', 4: 'leafless', 5: 'stalk', 6: 'stone', 7: 'trunk', 8: 'water', 9: 'wire'}
id2num = {
        '0' : class2num['broad leaves'],
        '1' : class2num['coniferous tree'],
        '2' : class2num['hard ground'],
        '3' : class2num['leafless'],
        '4' : class2num['stalk'],
        '5' : class2num['stone'],
        '6' : class2num['trunk'],
        '7' : class2num['grass land'],
        '8' : class2num['water'],
        '9' : class2num['wire'],
        }

# %%
imgs_folder = './samples'
imgs = [os.path.join(imgs_folder, fn) for fn in os.listdir(imgs_folder) if os.path.isfile(os.path.join(imgs_folder, fn))]
len(imgs), imgs[0]
# Out:
# (435, './samples\\000002.jpg')

# %%
im = imgs[0]
im.split(os.sep)[-1].split('.')[0]
# Out:
# '000002'

# %%
df = pd.DataFrame(imgs, columns=['original_fn'])
df['fn_id'] = df['original_fn'].apply(lambda x: x.split(os.sep)[-1].split('.')[0])
df['category'] = df['fn_id'].apply(lambda x: num2class[id2num[x[1]]])
df.sample(10)
# Out:
#               original_fn   fn_id         category
# 137  ./samples\030059.jpg  030059         leafless
# 422  ./samples\090146.jpg  090146             wire
# 122  ./samples\020188.jpg  020188      hard ground
# 223  ./samples\050032.jpg  050032            stone
# 306  ./samples\070012.jpg  070012       grass land
# 42   ./samples\010015.jpg  010015  coniferous tree
# 82   ./samples\010192.jpg  010192  coniferous tree
# 194  ./samples\040103.jpg  040103            stalk
# 255  ./samples\050195.jpg  050195            stone
# 206  ./samples\040184.jpg  040184            stalk

# %%
def pred_single_image(modelname, data_transforms, img_path):
    im = Image.open(img_path).convert("RGB")
    tsr = data_transforms(im).unsqueeze(0).to(device)
    outputs = models[modelname](tsr)
    probs = nn.functional.softmax(outputs, dim=1).squeeze()
    probs = probs.detach().numpy()
    pre_label_id = probs.argmax()
    true_label_id = imgName2num(img_path)
    true_label = num2class[true_label_id]
    pred_label = num2class[pre_label_id]
#     print(pre_label_id, true_label_id)
    is_correct = (pre_label_id==true_label_id)
#     print('Is correct:', is_correct, 'True Label:', true_label, 'Predicted Label:',pred_label)
    return is_correct, probs, true_label, pred_label

    
def imgName2num(image_path):
    baseName = os.path.basename(image_path)
    folder_id = baseName[1]
    id2num = {
        '0' : class2num['broad leaves'],
        '1' : class2num['coniferous tree'],
        '2' : class2num['hard ground'],
        '3' : class2num['leafless'],
        '4' : class2num['stalk'],
        '5' : class2num['stone'],
        '6' : class2num['trunk'],
        '7' : class2num['grass land'],
        '8' : class2num['water'],
        '9' : class2num['wire'],
    }
#     print(baseName, folder_id)
    return id2num[str(folder_id)]

# %%
alexnet = torch.load('alexnet-111_10_5_5.pkl', map_location=torch.device('cpu'))
vgg19 = torch.load('vgg19-111_8_5_5.pkl', map_location=torch.device('cpu'))
res50 = torch.load('resnet50-111_3_5_5.pkl', map_location=torch.device('cpu'))
res152 = torch.load('resnet152-111_5_5_5.pkl', map_location=torch.device('cpu'))

models = {
    'AlexNet'    :alexnet,
    'VGG19'     :vgg19,
    'ResNet50'  :res50,
    'ResNet152' :res152
}
resize = 224
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]
device = torch.device('cpu')

data_transforms = transforms.Compose([
    transforms.Resize((resize, resize)),
    transforms.ToTensor(),
    transforms.Normalize(mean, std)
    ])


model_name = 'ResNet152'

image_path = './samples/000019.jpg'
is_correct, probs, true_label, pred_label = pred_single_image(model_name, data_transforms, image_path)

# %%
is_correct, probs, true_label, pred_label
# Out:
# (False, array([2.1285194e-01, 8.1009112e-02, 3.1676289e-04, 8.6702566e-05,
#         6.9990057e-01, 8.3827542e-04, 8.0934225e-04, 3.7944631e-03,
#         2.0049032e-04, 1.9238006e-04], dtype=float32), 'broad leaves', 'leafless')

# %%
columns = ['image', 'Ground Truth', 'AlexNet', 'VGG19', 'ResNet50', 'ResNet152']
pred_results = []
for i,img in enumerate(imgs):
    _,_,gt,pred_label_AlexNet = pred_single_image('AlexNet', data_transforms, img)
    _,_,_,pred_label_VGG19 = pred_single_image('VGG19', data_transforms, img)
    _,_,_,pred_label_ResNet50 = pred_single_image('ResNet50', data_transforms, img)
    _,_,_,pred_label_ResNet152 = pred_single_image('ResNet152', data_transforms, img)
    
    print(i, gt, pred_label_AlexNet, pred_label_VGG19, pred_label_ResNet50, pred_label_ResNet152)
    pred_results.append([img, gt, pred_label_AlexNet, pred_label_VGG19, pred_label_ResNet50, pred_label_ResNet152])
# Out:
# 0 broad leaves broad leaves broad leaves broad leaves broad leaves
# 1 broad leaves broad leaves broad leaves broad leaves broad leaves
# 2 broad leaves coniferous tree broad leaves broad leaves broad leaves
# 3 broad leaves broad leaves broad leaves broad leaves broad leaves
# 4 broad leaves leafless leafless leafless leafless
# 5 broad leaves broad leaves broad leaves broad leaves broad leaves
# 6 broad leaves broad leaves stalk broad leaves broad leaves
# 7 broad leaves broad leaves broad leaves broad leaves broad leaves
# 8 broad leaves broad leaves broad leaves broad leaves broad leaves
# 9 broad leaves broad leaves broad leaves broad leaves broad leaves
# 10 broad leaves broad leaves broad leaves broad leaves broad leaves
# 11 broad leaves broad leaves broad leaves broad leaves broad leaves
# 12 broad leaves broad leaves broad leaves broad leaves broad leaves
# 13 broad leaves broad leaves broad leaves broad leaves broad leaves
# 14 broad leaves broad leaves broad leaves broad leaves broad leaves
# 15 broad leaves broad leaves broad leaves broad leaves broad leaves
# 16 broad leaves broad leaves broad leaves broad leaves broad leaves
# 17 broad leaves broad leaves broad leaves broad leaves broad leaves
# 18 broad leaves broad leaves broad leaves broad leaves broad leaves
# 19 broad leaves broad leaves stalk broad leaves broad leaves
# 20 broad leaves broad leaves broad leaves broad leaves broad leaves
# 21 broad leaves broad leaves broad leaves broad leaves broad leaves
# 22 broad leaves broad leaves broad leaves broad leaves broad leaves
# 23 broad leaves broad leaves broad leaves broad leaves broad leaves
# 24 broad leaves broad leaves broad leaves broad leaves broad leaves
# 25 broad leaves broad leaves broad leaves broad leaves broad leaves
# 26 broad leaves broad leaves broad leaves broad leaves broad leaves
# 27 broad leaves broad leaves broad leaves broad leaves broad leaves
# 28 broad leaves broad leaves broad leaves broad leaves broad leaves
# 29 broad leaves broad leaves broad leaves broad leaves broad leaves
# 30 broad leaves broad leaves broad leaves broad leaves broad leaves
# 31 broad leaves broad leaves broad leaves broad leaves broad leaves
# 32 broad leaves broad leaves broad leaves broad leaves broad leaves
# 33 broad leaves broad leaves broad leaves broad leaves broad leaves
# 34 broad leaves broad leaves broad leaves broad leaves broad leaves
# 35 broad leaves broad leaves broad leaves broad leaves broad leaves
# 36 broad leaves broad leaves broad leaves broad leaves broad leaves
# 37 broad leaves broad leaves broad leaves broad leaves broad leaves
# 38 broad leaves broad leaves broad leaves broad leaves broad leaves
# 39 broad leaves broad leaves broad leaves broad leaves broad leaves
# 40 broad leaves broad leaves broad leaves broad leaves broad leaves
# 41 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 42 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 43 coniferous tree broad leaves coniferous tree coniferous tree coniferous tree
# 44 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 45 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 46 coniferous tree broad leaves coniferous tree coniferous tree coniferous tree
# 47 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 48 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 49 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 50 coniferous tree wire wire wire wire
# 51 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 52 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 53 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 54 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 55 coniferous tree leafless coniferous tree coniferous tree coniferous tree
# 56 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 57 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 58 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 59 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 60 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 61 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 62 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 63 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 64 coniferous tree stalk coniferous tree coniferous tree coniferous tree
# 65 coniferous tree coniferous tree grass land coniferous tree coniferous tree
# 66 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 67 coniferous tree broad leaves coniferous tree coniferous tree coniferous tree
# 68 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 69 coniferous tree coniferous tree trunk trunk trunk
# 70 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 71 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 72 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 73 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 74 coniferous tree stone stone coniferous tree coniferous tree
# 75 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 76 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 77 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 78 coniferous tree grass land coniferous tree coniferous tree coniferous tree
# 79 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 80 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 81 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 82 coniferous tree coniferous tree coniferous tree coniferous tree coniferous tree
# 83 hard ground hard ground hard ground hard ground hard ground
# 84 hard ground hard ground hard ground hard ground hard ground
# 85 hard ground hard ground hard ground hard ground hard ground
# 86 hard ground hard ground hard ground hard ground hard ground
# 87 hard ground hard ground hard ground hard ground hard ground
# 88 hard ground hard ground hard ground hard ground hard ground
# 89 hard ground hard ground hard ground hard ground hard ground
# 90 hard ground hard ground hard ground hard ground hard ground
# 91 hard ground hard ground hard ground hard ground hard ground
# 92 hard ground stalk hard ground hard ground hard ground
# 93 hard ground hard ground hard ground hard ground hard ground
# 94 hard ground hard ground hard ground hard ground hard ground
# 95 hard ground hard ground hard ground hard ground hard ground
# 96 hard ground hard ground hard ground hard ground hard ground
# 97 hard ground hard ground hard ground hard ground hard ground
# 98 hard ground hard ground hard ground hard ground hard ground
# 99 hard ground hard ground hard ground hard ground hard ground
# 100 hard ground hard ground hard ground hard ground hard ground
# 101 hard ground hard ground hard ground hard ground hard ground
# 102 hard ground stone stone stone stone
# 103 hard ground water hard ground hard ground hard ground
# 104 hard ground hard ground hard ground hard ground hard ground
# 105 hard ground hard ground hard ground hard ground hard ground
# 106 hard ground hard ground hard ground hard ground hard ground
# 107 hard ground hard ground hard ground hard ground hard ground
# 108 hard ground water hard ground water hard ground
# 109 hard ground hard ground hard ground hard ground hard ground
# 110 hard ground hard ground hard ground hard ground hard ground
# 111 hard ground hard ground hard ground hard ground hard ground
# 112 hard ground hard ground hard ground hard ground hard ground
# 113 hard ground hard ground hard ground hard ground hard ground
# 114 hard ground hard ground hard ground hard ground hard ground
# 115 hard ground hard ground hard ground hard ground hard ground
# 116 hard ground hard ground hard ground hard ground hard ground
# 117 hard ground hard ground hard ground hard ground hard ground
# 118 hard ground hard ground hard ground hard ground hard ground
# 119 hard ground hard ground hard ground hard ground hard ground
# 120 hard ground hard ground hard ground hard ground hard ground
# 121 hard ground hard ground hard ground hard ground hard ground
# 122 hard ground water hard ground hard ground hard ground
# 123 hard ground hard ground hard ground hard ground hard ground
# 124 leafless wire wire leafless leafless
# 125 leafless leafless leafless leafless leafless
# 126 leafless leafless leafless leafless leafless
# 127 leafless leafless leafless leafless leafless
# 128 leafless leafless leafless leafless leafless
# 129 leafless leafless leafless leafless leafless
# 130 leafless leafless leafless leafless leafless
# 131 leafless leafless leafless leafless leafless
# 132 leafless leafless leafless leafless leafless
# 133 leafless leafless leafless leafless leafless
# 134 leafless wire leafless leafless leafless
# 135 leafless leafless leafless leafless leafless
# 136 leafless leafless leafless leafless leafless
# 137 leafless leafless leafless leafless leafless
# 138 leafless wire wire leafless leafless
# 139 leafless leafless leafless stalk stalk
# 140 leafless leafless leafless leafless leafless
# 141 leafless leafless leafless leafless leafless
# 142 leafless wire leafless leafless leafless
# 143 leafless leafless stalk stalk leafless
# 144 leafless leafless leafless leafless leafless
# 145 leafless leafless leafless leafless leafless
# 146 leafless leafless leafless leafless leafless
# 147 leafless leafless leafless leafless leafless
# 148 leafless leafless leafless leafless leafless
# 149 leafless leafless leafless leafless leafless
# 150 leafless wire leafless leafless leafless
# 151 leafless leafless leafless leafless leafless
# 152 leafless leafless leafless leafless leafless
# 153 leafless leafless leafless leafless leafless
# 154 leafless stone stone leafless leafless
# 155 leafless leafless leafless leafless leafless
# 156 leafless leafless leafless leafless leafless
# 157 leafless leafless leafless leafless leafless
# 158 leafless leafless leafless stalk stalk
# 159 leafless leafless leafless leafless leafless
# 160 leafless wire leafless leafless stalk
# 161 leafless leafless leafless leafless leafless
# 162 leafless leafless stalk leafless leafless
# 163 leafless leafless stalk stalk leafless
# 164 leafless leafless leafless leafless leafless
# 165 leafless stalk stalk stalk stalk
# 166 leafless leafless leafless leafless leafless
# 167 leafless stalk stalk stalk stalk
# 168 leafless leafless leafless leafless leafless
# 169 leafless leafless leafless leafless leafless
# 170 leafless leafless leafless leafless leafless
# 171 stalk stalk stalk stalk stalk
# 172 stalk stalk stalk stalk stalk
# 173 stalk stalk stalk stalk stalk
# 174 stalk stalk stalk stalk stalk
# 175 stalk stalk stalk stalk stalk
# 176 stalk stalk stalk stalk stalk
# 177 stalk stalk stalk stalk stalk
# 178 stalk stalk stalk stalk stalk
# 179 stalk stalk stalk stalk stalk
# 180 stalk stalk stalk stalk stalk
# 181 stalk stalk stalk stalk stalk
# 182 stalk broad leaves stalk stalk stalk
# 183 stalk stalk stalk stalk stalk
# 184 stalk stalk stalk stalk stalk
# 185 stalk stalk stalk stalk stalk
# 186 stalk stalk broad leaves broad leaves broad leaves
# 187 stalk stalk stalk stalk stalk
# 188 stalk stalk stalk stalk stalk
# 189 stalk stalk stalk stalk stalk
# 190 stalk broad leaves stalk stalk broad leaves
# 191 stalk stalk stalk stalk stalk
# 192 stalk stalk stalk stalk stalk
# 193 stalk wire wire stalk stalk
# 194 stalk stalk stalk stalk stalk
# 195 stalk stalk stalk leafless leafless
# 196 stalk stalk stalk stalk stalk
# 197 stalk stalk stalk stalk stalk
# 198 stalk stalk stalk stalk stalk
# 199 stalk stalk stalk stalk stalk
# 200 stalk stalk stalk stalk stalk
# 201 stalk leafless stalk leafless leafless
# 202 stalk broad leaves coniferous tree grass land grass land
# 203 stalk stalk stalk stalk stalk
# 204 stalk stalk stalk stalk stalk
# 205 stalk stalk stalk stalk stalk
# 206 stalk stalk stalk stalk stalk
# 207 stalk stalk stalk stalk stalk
# 208 stalk stalk stalk stalk stalk
# 209 stalk stalk stalk stalk stalk
# 210 stalk stalk stalk stalk stalk
# 211 stalk stalk stalk stalk stalk
# 212 stalk stalk stalk stalk stalk
# 213 stalk stalk stalk stalk stalk
# 214 stalk stalk stalk stalk stalk
# 215 stalk stalk stalk stalk stalk
# 216 stalk stalk stalk stalk stalk
# 217 stalk stalk stalk stalk stalk
# 218 stone stone stone stone stone
# 219 stone stone stone stone stone
# 220 stone stone stone stone stone
# 221 stone stone stone stone stone
# 222 stone stone stone stone stone
# 223 stone stone stone stone stone
# 224 stone stone stone stone stone
# 225 stone stone stone stone stone
# 226 stone stone stone stone stone
# 227 stone grass land grass land grass land grass land
# 228 stone stone stone stone stone
# 229 stone stone stone stone stone
# 230 stone stone stone stone stone
# 231 stone stone stone stone stone
# 232 stone water stone stone stone
# 233 stone coniferous tree broad leaves coniferous tree stone
# 234 stone stone stone stone stone
# 235 stone stone stone stone stone
# 236 stone stone stone stone stone
# 237 stone stone stone stone stone
# 238 stone stone stone stone stone
# 239 stone stone stone stone stone
# 240 stone stone stone stone stone
# 241 stone stone stone stone stone
# 242 stone trunk stone stone stone
# 243 stone stone stone stone stone
# 244 stone stone stone stone stone
# 245 stone stone stone stone stone
# 246 stone leafless stone stone stone
# 247 stone stone stone stone stone
# 248 stone stone stone stone stone
# 249 stone stone stone stone stone
# 250 stone stone water stone water
# 251 stone stone stone stone stone
# 252 stone stone stone stone stone
# 253 stone stone stone stone stone
# 254 stone stone stone stone stone
# 255 stone stone stone stone trunk
# 256 stone stone stone stone stone
# 257 stone stone stone stone stone
# 258 stone stone stone stone stone
# 259 stone stone stone stone stone
# 260 trunk trunk trunk trunk trunk
# 261 trunk trunk trunk trunk trunk
# 262 trunk trunk trunk trunk trunk
# 263 trunk trunk trunk trunk trunk
# 264 trunk trunk trunk trunk trunk
# 265 trunk trunk trunk trunk trunk
# 266 trunk trunk trunk trunk trunk
# 267 trunk trunk trunk trunk trunk
# 268 trunk trunk trunk trunk trunk
# 269 trunk leafless trunk trunk trunk
# 270 trunk trunk trunk trunk trunk
# 271 trunk leafless leafless leafless leafless
# 272 trunk trunk trunk trunk trunk
# 273 trunk trunk trunk trunk trunk
# 274 trunk trunk trunk trunk trunk
# 275 trunk trunk trunk trunk trunk
# 276 trunk trunk trunk trunk trunk
# 277 trunk trunk trunk trunk trunk
# 278 trunk leafless trunk trunk trunk
# 279 trunk trunk trunk trunk trunk
# 280 trunk trunk trunk trunk trunk
# 281 trunk trunk trunk trunk trunk
# 282 trunk trunk trunk trunk trunk
# 283 trunk trunk trunk trunk trunk
# 284 trunk trunk trunk trunk trunk
# 285 trunk trunk trunk trunk trunk
# 286 trunk trunk trunk trunk trunk
# 287 trunk trunk stalk trunk trunk
# 288 trunk trunk trunk trunk trunk
# 289 trunk trunk trunk trunk trunk
# 290 trunk trunk trunk trunk trunk
# 291 trunk trunk trunk trunk trunk
# 292 trunk trunk trunk trunk trunk
# 293 trunk trunk trunk trunk trunk
# 294 trunk trunk trunk trunk trunk
# 295 trunk trunk trunk trunk trunk
# 296 trunk trunk trunk trunk trunk
# 297 trunk trunk trunk trunk trunk
# 298 trunk trunk trunk trunk trunk
# 299 trunk trunk trunk trunk trunk
# 300 trunk trunk trunk trunk trunk
# 301 trunk trunk trunk trunk trunk
# 302 trunk trunk trunk trunk trunk
# 303 trunk trunk trunk trunk trunk
# 304 grass land grass land grass land grass land grass land
# 305 grass land grass land grass land grass land grass land
# 306 grass land grass land grass land grass land grass land
# 307 grass land grass land grass land grass land grass land
# 308 grass land grass land grass land grass land grass land
# 309 grass land grass land grass land grass land grass land
# 310 grass land grass land grass land grass land grass land
# 311 grass land grass land grass land grass land grass land
# 312 grass land grass land grass land grass land grass land
# 313 grass land grass land grass land grass land grass land
# 314 grass land grass land grass land grass land grass land
# 315 grass land grass land grass land grass land grass land
# 316 grass land coniferous tree grass land grass land grass land
# 317 grass land grass land grass land stone stone
# 318 grass land grass land grass land grass land grass land
# 319 grass land grass land grass land grass land grass land
# 320 grass land grass land grass land grass land grass land
# 321 grass land grass land grass land grass land grass land
# 322 grass land grass land grass land grass land grass land
# 323 grass land grass land grass land grass land grass land
# 324 grass land grass land grass land grass land grass land
# 325 grass land grass land grass land grass land grass land
# 326 grass land grass land grass land grass land grass land
# 327 grass land grass land grass land grass land grass land
# 328 grass land grass land grass land grass land grass land
# 329 grass land grass land grass land grass land grass land
# 330 grass land grass land grass land grass land grass land
# 331 grass land grass land grass land grass land grass land
# 332 grass land grass land grass land grass land grass land
# 333 grass land broad leaves grass land grass land grass land
# 334 grass land grass land grass land grass land grass land
# 335 grass land grass land grass land grass land grass land
# 336 grass land grass land grass land grass land grass land
# 337 grass land grass land grass land grass land grass land
# 338 grass land grass land grass land grass land grass land
# 339 grass land grass land grass land grass land grass land
# 340 grass land grass land grass land grass land grass land
# 341 grass land grass land grass land grass land grass land
# 342 grass land grass land grass land grass land grass land
# 343 grass land grass land grass land grass land grass land
# 344 grass land grass land grass land grass land grass land
# 345 water water water water water
# 346 water water water water water
# 347 water water water water water
# 348 water water water water water
# 349 water water water water water
# 350 water water water water water
# 351 water water water water water
# 352 water water water water water
# 353 water water water water water
# 354 water water water water water
# 355 water water water water water
# 356 water water water water water
# 357 water water water water water
# 358 water water water water water
# 359 water water water water water
# 360 water water water water water
# 361 water water water water water
# 362 water water water water water
# 363 water water water water water
# 364 water water water water water
# 365 water water water water water
# 366 water water water water water
# 367 water water water water water
# 368 water water water water water
# 369 water water water water water
# 370 water water water water water
# 371 water water water water water
# 372 water water water water water
# 373 water water water water water
# 374 water water water water water
# 375 water water water water water
# 376 water water water water water
# 377 water water water water water
# 378 water water water water water
# 379 water water water water water
# 380 water water water water water
# 381 water water water water water
# 382 water water water water water
# 383 water water water water water
# 384 water water water water water
# 385 water water water water water
# 386 water water water water water
# 387 water water water water water
# 388 water water water water water
# 389 water water water water water
# 390 water water water water water
# 391 wire wire wire wire wire
# 392 wire wire wire wire wire
# 393 wire wire wire wire wire
# 394 wire wire wire wire wire
# 395 wire stalk wire stalk stalk
# 396 wire wire wire wire wire
# 397 wire wire wire wire wire
# 398 wire wire wire wire wire
# 399 wire wire wire wire wire
# 400 wire wire wire wire wire
# 401 wire wire wire wire wire
# 402 wire wire wire wire wire
# 403 wire wire wire wire wire
# 404 wire wire wire wire wire
# 405 wire wire wire wire wire
# 406 wire wire wire wire wire
# 407 wire wire wire wire wire
# 408 wire wire wire wire wire
# 409 wire wire wire wire wire
# 410 wire wire wire wire wire
# 411 wire wire wire wire wire
# 412 wire wire wire wire wire
# 413 wire wire wire wire wire
# 414 wire wire wire wire wire
# 415 wire wire wire wire wire
# 416 wire wire wire wire wire
# 417 wire wire wire leafless wire
# 418 wire wire wire wire wire
# 419 wire wire wire wire wire
# 420 wire wire wire wire wire
# 421 wire wire wire wire wire
# 422 wire wire wire wire wire
# 423 wire wire wire wire wire
# 424 wire wire wire wire wire
# 425 wire wire wire wire wire
# 426 wire wire wire wire wire
# 427 wire wire wire wire wire
# 428 wire wire wire wire wire
# 429 wire wire wire wire wire
# 430 wire wire wire wire wire
# 431 wire wire wire wire wire
# 432 wire wire wire wire wire
# 433 wire wire wire wire wire
# 434 wire wire wire wire wire

# %%
df = pd.DataFrame(pred_results, columns=columns)
df.head()
# Out:
#                   image  Ground Truth          AlexNet         VGG19  \
# 0  ./samples\000002.jpg  broad leaves     broad leaves  broad leaves
# 1  ./samples\000003.jpg  broad leaves     broad leaves  broad leaves
# 2  ./samples\000009.jpg  broad leaves  coniferous tree  broad leaves
# 3  ./samples\000010.jpg  broad leaves     broad leaves  broad leaves
# 4  ./samples\000019.jpg  broad leaves         leafless      leafless
#
#        ResNet50     ResNet152
# 0  broad leaves  broad leaves
# 1  broad leaves  broad leaves
# 2  broad leaves  broad leaves
# 3  broad leaves  broad leaves
# 4      leafless      leafless

# %%
class_names = list(class2num.keys())

# %%
from sklearn.metrics import classification_report, confusion_matrix
from scikitplot.metrics import plot_roc, plot_precision_recall

print(classification_report(y_true=df['Ground Truth'], y_pred=df['AlexNet'], target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
#    broad leaves       0.85      0.95      0.90        41
# coniferous tree       0.92      0.81      0.86        42
#      grass land       0.95      0.95      0.95        41
#     hard ground       1.00      0.88      0.94        41
#        leafless       0.84      0.81      0.83        47
#           stalk       0.89      0.89      0.89        47
#           stone       0.93      0.88      0.90        42
#           trunk       0.98      0.93      0.95        44
#           water       0.92      1.00      0.96        46
#            wire       0.84      0.98      0.91        44
#
#        accuracy                           0.91       435
#       macro avg       0.91      0.91      0.91       435
#    weighted avg       0.91      0.91      0.91       435

# %%
print(classification_report(y_true=df['Ground Truth'], y_pred=df['VGG19'], target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
#    broad leaves       0.95      0.93      0.94        41
# coniferous tree       0.97      0.90      0.94        42
#      grass land       0.95      1.00      0.98        41
#     hard ground       1.00      0.98      0.99        41
#        leafless       0.95      0.83      0.89        47
#           stalk       0.85      0.94      0.89        47
#           stone       0.93      0.93      0.93        42
#           trunk       0.98      0.95      0.97        44
#           water       0.98      1.00      0.99        46
#            wire       0.92      1.00      0.96        44
#
#        accuracy                           0.94       435
#       macro avg       0.95      0.95      0.95       435
#    weighted avg       0.95      0.94      0.94       435

# %%
print(classification_report(y_true=df['Ground Truth'], y_pred=df['ResNet50'], target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
#    broad leaves       0.98      0.98      0.98        41
# coniferous tree       0.98      0.95      0.96        42
#      grass land       0.95      0.98      0.96        41
#     hard ground       1.00      0.95      0.97        41
#        leafless       0.89      0.87      0.88        47
#           stalk       0.86      0.91      0.89        47
#           stone       0.95      0.95      0.95        42
#           trunk       0.98      0.98      0.98        44
#           water       0.98      1.00      0.99        46
#            wire       0.98      0.95      0.97        44
#
#        accuracy                           0.95       435
#       macro avg       0.95      0.95      0.95       435
#    weighted avg       0.95      0.95      0.95       435

# %%
print(classification_report(y_true=df['Ground Truth'], y_pred=df['ResNet152'], target_names=class_names))
# Out:
#                  precision    recall  f1-score   support
#
#    broad leaves       0.95      0.98      0.96        41
# coniferous tree       1.00      0.95      0.98        42
#      grass land       0.95      0.98      0.96        41
#     hard ground       1.00      0.98      0.99        41
#        leafless       0.91      0.89      0.90        47
#           stalk       0.88      0.89      0.88        47
#           stone       0.95      0.93      0.94        42
#           trunk       0.96      0.98      0.97        44
#           water       0.98      1.00      0.99        46
#            wire       0.98      0.98      0.98        44
#
#        accuracy                           0.95       435
#       macro avg       0.96      0.95      0.96       435
#    weighted avg       0.95      0.95      0.95       435

# %% [markdown]
# # Confuse Matrix Show

# %%
confusion_matrix_AlexNet = pd.DataFrame(confusion_matrix(y_true=df['Ground Truth'], y_pred=df['AlexNet']), index=class_names, columns=class_names)
confusion_matrix_VGG19 = pd.DataFrame(confusion_matrix(y_true=df['Ground Truth'], y_pred=df['VGG19']), index=class_names, columns=class_names)
confusion_matrix_ResNet50 = pd.DataFrame(confusion_matrix(y_true=df['Ground Truth'], y_pred=df['ResNet50']), index=class_names, columns=class_names)
confusion_matrix_ResNet152 = pd.DataFrame(confusion_matrix(y_true=df['Ground Truth'], y_pred=df['ResNet152']), index=class_names, columns=class_names)

# %% [markdown]
# ## AlexNet

# %%
confusion_matrix_AlexNet
# Out:
#                  broad leaves  coniferous tree  grass land  hard ground  \
# broad leaves               39                1           0            0
# coniferous tree             3               34           1            0
# grass land                  1                1          39            0
# hard ground                 0                0           0           36
# leafless                    0                0           0            0
# stalk                       3                0           0            0
# stone                       0                1           1            0
# trunk                       0                0           0            0
# water                       0                0           0            0
# wire                        0                0           0            0
#
#                  leafless  stalk  stone  trunk  water  wire
# broad leaves            1      0      0      0      0     0
# coniferous tree         1      1      1      0      0     1
# grass land              0      0      0      0      0     0
# hard ground             0      1      1      0      3     0
# leafless               38      2      1      0      0     6
# stalk                   1     42      0      0      0     1
# stone                   1      0     37      1      1     0
# trunk                   3      0      0     41      0     0
# water                   0      0      0      0     46     0
# wire                    0      1      0      0      0    43

# %% [markdown]
# ## VGG19

# %%
confusion_matrix_VGG19
# Out:
#                  broad leaves  coniferous tree  grass land  hard ground  \
# broad leaves               38                0           0            0
# coniferous tree             0               38           1            0
# grass land                  0                0          41            0
# hard ground                 0                0           0           40
# leafless                    0                0           0            0
# stalk                       1                1           0            0
# stone                       1                0           1            0
# trunk                       0                0           0            0
# water                       0                0           0            0
# wire                        0                0           0            0
#
#                  leafless  stalk  stone  trunk  water  wire
# broad leaves            1      2      0      0      0     0
# coniferous tree         0      0      1      1      0     1
# grass land              0      0      0      0      0     0
# hard ground             0      0      1      0      0     0
# leafless               39      5      1      0      0     2
# stalk                   0     44      0      0      0     1
# stone                   0      0     39      0      1     0
# trunk                   1      1      0     42      0     0
# water                   0      0      0      0     46     0
# wire                    0      0      0      0      0    44

# %% [markdown]
# ## ResNet50

# %%
confusion_matrix_ResNet50
# Out:
#                  broad leaves  coniferous tree  grass land  hard ground  \
# broad leaves               40                0           0            0
# coniferous tree             0               40           0            0
# grass land                  0                0          40            0
# hard ground                 0                0           0           39
# leafless                    0                0           0            0
# stalk                       1                0           1            0
# stone                       0                1           1            0
# trunk                       0                0           0            0
# water                       0                0           0            0
# wire                        0                0           0            0
#
#                  leafless  stalk  stone  trunk  water  wire
# broad leaves            1      0      0      0      0     0
# coniferous tree         0      0      0      1      0     1
# grass land              0      0      1      0      0     0
# hard ground             0      0      1      0      1     0
# leafless               41      6      0      0      0     0
# stalk                   2     43      0      0      0     0
# stone                   0      0     40      0      0     0
# trunk                   1      0      0     43      0     0
# water                   0      0      0      0     46     0
# wire                    1      1      0      0      0    42

# %% [markdown]
# ## ResNet152

# %%
confusion_matrix_ResNet152
# Out:
#                  broad leaves  coniferous tree  grass land  hard ground  \
# broad leaves               40                0           0            0
# coniferous tree             0               40           0            0
# grass land                  0                0          40            0
# hard ground                 0                0           0           40
# leafless                    0                0           0            0
# stalk                       2                0           1            0
# stone                       0                0           1            0
# trunk                       0                0           0            0
# water                       0                0           0            0
# wire                        0                0           0            0
#
#                  leafless  stalk  stone  trunk  water  wire
# broad leaves            1      0      0      0      0     0
# coniferous tree         0      0      0      1      0     1
# grass land              0      0      1      0      0     0
# hard ground             0      0      1      0      0     0
# leafless               42      5      0      0      0     0
# stalk                   2     42      0      0      0     0
# stone                   0      0     39      1      1     0
# trunk                   1      0      0     43      0     0
# water                   0      0      0      0     46     0
# wire                    0      1      0      0      0    43

# %% [raw]
#                   precision    recall  f1-score   support
# AlexNet
#    broad leaves       0.85      0.95      0.90        41
# coniferous tree       0.92      0.81      0.86        42
#      grass land       0.95      0.95      0.95        41
#     hard ground       1.00      0.88      0.94        41
#        leafless       0.84      0.81      0.83        47
#           stalk       0.89      0.89      0.89        47
#           stone       0.93      0.88      0.90        42
#           trunk       0.98      0.93      0.95        44
#           water       0.92      1.00      0.96        46
#            wire       0.84      0.98      0.91        44
#
#        accuracy                           0.91       435
#       macro avg       0.91      0.91      0.91       435
#    weighted avg       0.91      0.91      0.91       435
#
# VGG9
#    broad leaves       0.95      0.93      0.94        41
# coniferous tree       0.97      0.90      0.94        42
#      grass land       0.95      1.00      0.98        41
#     hard ground       1.00      0.98      0.99        41
#        leafless       0.95      0.83      0.89        47
#           stalk       0.85      0.94      0.89        47
#           stone       0.93      0.93      0.93        42
#           trunk       0.98      0.95      0.97        44
#           water       0.98      1.00      0.99        46
#            wire       0.92      1.00      0.96        44
#
#        accuracy                           0.94       435
#       macro avg       0.95      0.95      0.95       435
#    weighted avg       0.95      0.94      0.94       435
#
# ResNet50
#    broad leaves       0.98      0.98      0.98        41
# coniferous tree       0.98      0.95      0.96        42
#      grass land       0.95      0.98      0.96        41
#     hard ground       1.00      0.95      0.97        41
#        leafless       0.89      0.87      0.88        47
#           stalk       0.86      0.91      0.89        47
#           stone       0.95      0.95      0.95        42
#           trunk       0.98      0.98      0.98        44
#           water       0.98      1.00      0.99        46
#            wire       0.98      0.95      0.97        44
#
#        accuracy                           0.95       435
#       macro avg       0.95      0.95      0.95       435
#    weighted avg       0.95      0.95      0.95       435
#
# ResNet152
#    broad leaves       0.95      0.98      0.96        41
# coniferous tree       1.00      0.95      0.98        42
#      grass land       0.95      0.98      0.96        41
#     hard ground       1.00      0.98      0.99        41
#        leafless       0.91      0.89      0.90        47
#           stalk       0.88      0.89      0.88        47
#           stone       0.95      0.93      0.94        42
#           trunk       0.96      0.98      0.97        44
#           water       0.98      1.00      0.99        46
#            wire       0.98      0.98      0.98        44
#
#        accuracy                           0.95       435
#       macro avg       0.96      0.95      0.96       435
#    weighted avg       0.95      0.95      0.95       435

# %% [raw]
#    broad leaves       0.85      0.95      0.90        41
# coniferous tree       0.92      0.81      0.86        42
#      grass land       0.95      0.95      0.95        41
#     hard ground       1.00      0.88      0.94        41
#        leafless       0.84      0.81      0.83        47
#           stalk       0.89      0.89      0.89        47
#           stone       0.93      0.88      0.90        42
#           trunk       0.98      0.93      0.95        44
#           water       0.92      1.00      0.96        46
#            wire       0.84      0.98      0.91        44
#    broad leaves       0.95      0.93      0.94        41
# coniferous tree       0.97      0.90      0.94        42
#      grass land       0.95      1.00      0.98        41
#     hard ground       1.00      0.98      0.99        41
#        leafless       0.95      0.83      0.89        47
#           stalk       0.85      0.94      0.89        47
#           stone       0.93      0.93      0.93        42
#           trunk       0.98      0.95      0.97        44
#           water       0.98      1.00      0.99        46
#            wire       0.92      1.00      0.96        44
#    broad leaves       0.98      0.98      0.98        41
# coniferous tree       0.98      0.95      0.96        42
#      grass land       0.95      0.98      0.96        41
#     hard ground       1.00      0.95      0.97        41
#        leafless       0.89      0.87      0.88        47
#           stalk       0.86      0.91      0.89        47
#           stone       0.95      0.95      0.95        42
#           trunk       0.98      0.98      0.98        44
#           water       0.98      1.00      0.99        46
#            wire       0.98      0.95      0.97        44
#    broad leaves       0.95      0.98      0.96        41
# coniferous tree       1.00      0.95      0.98        42
#      grass land       0.95      0.98      0.96        41
#     hard ground       1.00      0.98      0.99        41
#        leafless       0.91      0.89      0.90        47
#           stalk       0.88      0.89      0.88        47
#           stone       0.95      0.93      0.94        42
#           trunk       0.96      0.98      0.97        44
#           water       0.98      1.00      0.99        46
#            wire       0.98      0.98      0.98        44
